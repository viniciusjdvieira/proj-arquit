# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Nova seção

# %%
pathi = '/content/drive/MyDrive/proj_arq_2023'
os.system('ls -l /content/drive/MyDrive/proj_arq_2023/')
# Out:
# 0

# %%
pd.read_pickle('/content/drive/MyDrive/proj_arq_2023/dataset_medias_kay_v1.pkl')
# Out:
#      Unnamed: 0                                            caminho  \
# 0             0  C:\Users\vinic\Documents\datasets\sinais_renom...
# 1             1  C:\Users\vinic\Documents\datasets\sinais_renom...
# 2             2  C:\Users\vinic\Documents\datasets\sinais_renom...
# 3             3  C:\Users\vinic\Documents\datasets\sinais_renom...
# 4             4  C:\Users\vinic\Documents\datasets\sinais_renom...
# ..          ...                                                ...
# 162         162  C:\Users\vinic\Documents\datasets\sinais_renom...
# 163         163  C:\Users\vinic\Documents\datasets\sinais_renom...
# 164         164  C:\Users\vinic\Documents\datasets\sinais_renom...
# 165         165  C:\Users\vinic\Documents\datasets\sinais_renom...
# 166         166  C:\Users\vinic\Documents\datasets\sinais_renom...
#
#          arquivo_wav arquivo_sem_wav     classe  index_na_classe  \
# 0         edema1.wav          edema1      edema                1
# ...

# %%
df_ptl = pd.read_pickle('/content/drive/MyDrive/proj_arq_2023/dataset_matrix_ptl_kay_v3.pkl')
df_ptl
# Out:
#          paciente     classe  idx_na_classe  classification      lpc1  \
# 0          edema1      edema              1               1 -0.433838
# 1          edema1      edema              1               1 -0.402344
# 2          edema1      edema              1               1 -0.553711
# 3          edema1      edema              1               1 -0.560547
# 4          edema1      edema              1               1 -0.569336
# ...           ...        ...            ...             ...       ...
# 13386  paralisia9  paralisia              9               1 -1.376953
# 13387  paralisia9  paralisia              9               1 -1.184570
# 13388  paralisia9  paralisia              9               1 -1.419922
# 13389  paralisia9  paralisia              9               1 -1.483398
# 13390  paralisia9  paralisia              9               1 -1.495117
#
#            lpc2      lpc3      lpc4      lpc5      lpc6  ...  minimoF2  \
# ...

# %%
df_sdl = pd.read_pickle('/content/drive/MyDrive/proj_arq_2023/dataset_matrix_sdl_kay_v3.pkl')
df_sdl
# Out:
#       paciente  classe  idx_na_classe  classification      lpc1      lpc2  \
# 0      normal1  normal              1               0 -2.132812  0.897949
# 1      normal1  normal              1               0 -2.064453  0.603516
# 2      normal1  normal              1               0 -1.978516  0.454590
# 3      normal1  normal              1               0 -2.011719  0.465820
# 4      normal1  normal              1               0 -2.050781  0.627441
# ...        ...     ...            ...             ...       ...       ...
# 15188  normal9  normal              9               0 -2.039062  1.610352
# 15189  normal9  normal              9               0 -1.884766  1.215820
# 15190  normal9  normal              9               0 -1.954102  1.412109
# 15191  normal9  normal              9               0 -2.044922  1.632812
# 15192  normal9  normal              9               0 -1.999023  1.503906
#
#            lpc3      lpc4      lpc5      lpc6  ...  minimoF2  maximoF2  \
# ...

# %%
# load the iris dataset and get X and Y data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
train = pd.DataFrame(iris.data)
test = pd.DataFrame(iris.target)

# %%
train
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
np.shape(train)
# Out:
# (150, 4)

# %%
np.shape(test)
# Out:
# (150, 1)

# %%
# set aside 20% of train and test data for evaluation
X_train, X_test, y_train, y_test = train_test_split(train, test,
    test_size=0.2, shuffle = True, random_state = 8)

# Use the same function above for the validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
    test_size=0.25, random_state= 8) # 0.25 x 0.8 = 0.2


print("X_train shape: {}".format(X_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("y_train shape: {}".format(y_train.shape))
print("y_test shape: {}".format(y_test.shape))
print("X_val shape: {}".format(y_train.shape))
print("y val shape: {}".format(y_test.shape))
# Out:
# X_train shape: (90, 4)
# X_test shape: (30, 4)
# y_train shape: (90, 1)
# y_test shape: (30, 1)
# X_val shape: (90, 1)
# y val shape: (30, 1)

# %%
train_df, validate, test = \
              np.split(train.sample(frac=1, random_state=42),
                       [int(.6*len(train)), int(.8*len(train))])

# %%
np.shape(train_df)
# Out:
# (90, 4)
